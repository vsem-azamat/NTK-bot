# %%
import joblib
import numpy as np
from datetime import datetime

from sklearn.metrics import mean_squared_error 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor

# %%
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/poryadok/miniconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.24.3               |  py311h08b1b3b_1          11 KB
#     numpy-base-1.24.3          |  py311hf175353_1         7.2 MB
#     scikit-learn-1.3.0         |  py311ha02d727_0         9.5 MB
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB
#     ------------------------------------------------------------
#                                            Total:        16.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   scikit-learn       pkgs/main/linux-64::scikit-learn-1.3.0-py311ha02d727_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
# The following packages will be DOWNGRADED:
#
#   numpy                              1.26.0-py311h08b1b3b_0 --> 1.24.3-py311h08b1b3b_1
#   numpy-base                         1.26.0-py311hf175353_0 --> 1.24.3-py311hf175353_1
#
#
#
# Downloading and Extracting Packages:
# scikit-learn-1.3.0   | 9.5 MB    |                                       |   0%
# numpy-base-1.24.3    | 7.2 MB    |                                       |   0%
#
# threadpoolctl-2.2.0  | 16 KB     |                                       |   0%
#
#
# numpy-1.24.3         | 11 KB     |                                       |   0%
#
# scikit-learn-1.3.0   | 9.5 MB    | #####2                                |  14%
#
#
# numpy-1.24.3         | 11 KB     | ##################################### | 100%
#
#
# numpy-1.24.3         | 11 KB     | ##################################### | 100%
# scikit-learn-1.3.0   | 9.5 MB    | ############6                         |  34%
# scikit-learn-1.3.0   | 9.5 MB    | ################4                     |  44%
# numpy-base-1.24.3    | 7.2 MB    | ##7                                   |   7%
# scikit-learn-1.3.0   | 9.5 MB    | ###################9                  |  54%
# scikit-learn-1.3.0   | 9.5 MB    | ########################2             |  66%
# scikit-learn-1.3.0   | 9.5 MB    | ################################3     |  88%
# numpy-base-1.24.3    | 7.2 MB    | #################                     |  46%
# scikit-learn-1.3.0   | 9.5 MB    | ####################################1 |  98%
# numpy-base-1.24.3    | 7.2 MB    | #######################1              |  63%
# numpy-base-1.24.3    | 7.2 MB    | #############################1        |  79%
# scikit-learn-1.3.0   | 9.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
